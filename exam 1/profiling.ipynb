# %% [markdown]
# ### DATA PROFILING

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv("customer purchase data.csv")
profile = ProfileReport(df, title="My Data Report")

profile.to_file("report.html")
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 1539.55it/s]<00:00, 32.45it/s, Describe variable: Churn]
# Summarize dataset: 100%|██████████| 54/54 [00:02<00:00, 18.32it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  4.15it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 166.65it/s]
